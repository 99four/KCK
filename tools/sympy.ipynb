# %%
from sympy.interactive import printing
printing.init_printing(use_latex=True)
import sympy as sym
# Definicje zmiennych
x, y = sym.symbols("x y")

# %%
eq1 = Eq(x**2 + 3*y - 10)
eq1
# Out:
#  2
# x  + 3⋅y - 10 = 0

# %%
eq2 = Eq(4*x - y**2 + 2)
eq2
# Out:
#        2
# 4⋅x - y  + 2 = 0

# %%
solve([eq1, eq2], x, y)
# Out:
# ⎡⎛
# ⎢⎜      ⎛
# ⎢⎜      ⎜
# ⎢⎜      ⎜
# ⎢⎜      ⎜
# ⎢⎜      ⎜          _________________________________________________________
# ⎢⎜      ⎜         ╱                                       _________________
# ⎢⎜      ⎜        ╱              928             8        ╱ 1072   16⋅√4873
# ⎢⎜      ⎜       ╱   - ─────────────────────── + ─ + 2⋅3 ╱  ──── + ────────
# ⎢⎜      ⎜      ╱            _________________   3     ╲╱    27       3
# ⎢⎜      ⎜     ╱            ╱ 1072   16⋅√4873
# ⎢⎜      ⎜    ╱        9⋅3 ╱  ──── + ────────
# ⎢⎜      ⎜  ╲╱           ╲╱    27       3
# ⎢⎜      ⎜- ───────────────────────────────────────────────────────────────── +
# ⎢⎜  1   ⎝                                  2
# ⎢⎜- ─ + ──────────────────────────────────────────────────────────────────────
# ⎣⎝  2
#
#
#              _________________________________________________________________
#             ╱         _________________
#            ╱         ╱ 1072   16⋅√4873    16             928
# ...

# %%
a = sin(log(x,2)) * cos(x**2)/x
a
# Out:
#    ⎛log(x)⎞    ⎛ 2⎞
# sin⎜──────⎟⋅cos⎝x ⎠
#    ⎝log(2)⎠
# ───────────────────
#          x

# %%
eqn = Eq(Derivative(a))
eqn
# Out:
#   ⎛   ⎛log(x)⎞    ⎛ 2⎞⎞
#   ⎜sin⎜──────⎟⋅cos⎝x ⎠⎟
# d ⎜   ⎝log(2)⎠        ⎟
# ──⎜───────────────────⎟ = 0
# dx⎝         x         ⎠

# %%
from matplotlib import pylab as plt
import numpy as np

x = np.arange(-5, 5, 0.1)
y = [i**3 + 3*i**2 - 10*i + 24 for i in x]
plt.plot(x, y)
plt.show()

# %%
x = sym.symbols("x")
eq = Eq = x**3 + 3*x**2 - 10*x + 24
solve(eq, x)
# Out:
# [-1 - 13/((-1/2 - sqrt(3)*I/2)*(3*sqrt(19653) + 486)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(3*sqrt(19653) + 486)**(1/3)/3, -1 - (-1/2 + sqrt(3)*I/2)*(3*sqrt(19653) + 486)**(1/3)/3 - 13/((-1/2 + sqrt(3)*I/2)*(3*sqrt(19653) + 486)**(1/3)), -(3*sqrt(19653) + 486)**(1/3)/3 - 13/(3*sqrt(19653) + 486)**(1/3) - 1]
